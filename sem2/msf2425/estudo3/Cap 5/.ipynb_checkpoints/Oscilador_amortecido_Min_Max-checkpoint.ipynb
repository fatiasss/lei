# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import sympy as sy
import math
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from scipy.signal import find_peaks
m= 0.25
k = 1
b=0.1
x0= 0.4
v0x= 0

# %%
N=100000
tfinal=20
xt= np.empty(N)
xt[0]=x0
vxt= np.empty(N)
vxt[0]=v0x
t = np.empty(N)
t[0] = 0

maximum = []
minimum = []

period_list = []
amp_list = []

dt=tfinal/N

# %%
def maxminv(x0,x1,x2,y0,y1,y2):
 # Máximo ou mínimo usando o polinómio de Lagrange
 # Dados (input): (x0,y0), (x1,y1) e (x2,y2)
 # Resultados (output): xm, ymax
 xab=x0-x1
 xac=x0-x2
 xbc=x1-x2
 a=y0/(xab*xac)
 b=-y1/(xab*xbc)
 c=y2/(xac*xbc)
 xmla=(b+c)*x0+(a+c)*x1+(a+b)*x2
 xm=0.5*xmla/(a+b+c)
 xta=xm-x0
 xtb=xm-x1
 xtc=xm-x2
 ymax=a*xtb*xtc+b*xta*xtc+c*xta*xtb
 return xm, ymax

# %%
def eulercromer():
    for i in range(N-1):
        ax=-(k*xt[i] + b*vxt[i])/m
        
        vxt[i+1]=vxt[i]+ax*dt
        xt[i+1]=xt[i]+vxt[i+1]*dt
        
        t[i+1]= t[i] + dt

        if xt[i-1] < xt[i] > xt[i+1]:
            t0, t1, t2 = (i-1)*dt, i*dt, (i+1)*dt
            y0, y1, y2 = xt[i-1], xt[i], xt[i+1]
            xm, xmax = maxminv(t0, t1, t2, y0, y1, y2)
            maximum.append([xm, xmax])
        if xt[i-1]> xt[i] < xt[i+1]:
            t0, t1, t2 = (i-1)*dt, i*dt, (i+1)*dt
            y0, y1, y2 = xt[i-1], xt[i], xt[i+1]
            xm, xmin = maxminv(t0, t1, t2, y0, y1, y2)
            minimum.append([xm, xmin])
        
    return
eulercromer()

# %%
figure, axis = plt.subplots(2,2)
axis[0,0].plot(t, xt, linestyle="-")
axis[0,0].set_xlabel("t (s)")
axis[0,0].set_ylabel("x (m)")
axis[0,1].plot(t, vxt, linestyle="-")
axis[0,1].set_xlabel("t (s)")
axis[0,1].set_ylabel("v (m/s)")
plt.axis('equal')
figure.tight_layout()

# %%
maxval= sum([sublist[1] for sublist in maximum])/len(maximum) #find max and min values
minval = max= sum([sublist[1] for sublist in minimum])/len(minimum)
print(minval, maxval)
# Out:
# -0.10148673245306594 0.12772155564527812

# %%
log_max = [math.log(abs(sublist[1])) for sublist in maximum]
tempos = [sublist[0] for sublist in maximum]
axis[1,0].scatter(tempos, log_max)
figure
