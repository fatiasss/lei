# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
g= 9.81
vt=6.80
v0= 250/3.6

# %%
t= sy.symbols("t")
yt = ((vt**2)/g)*sy.log(sy.cosh((g*t)/vt)) + v0*t
vy = sy.diff(yt, t) + v0*T
at = g - (g/(vt**2))*abs(vy)*vy

t_vals=np.linspace(0, 10, 1000)

vy_lam= sy.lambdify(t, vy, "numpy")
yt_lam= sy.lambdify(t, yt, "numpy")
at_lam= sy.lambdify(t, at, "numpy")
# Out:
# ---------------------------------------------------------------------------
# PrintMethodNotImplementedError            Traceback (most recent call last)
# Cell In[46], line 8
#       6 t_vals=np.linspace(0, 10, 1000)
#       7 at_lam= sy.lambdify(t, at, "numpy")
# ----> 8 vy_lam= sy.lambdify(t, vy, "numpy")
#       9 yt_lam= sy.lambdify(t, yt, "numpy")
#
# File C:\pythonhold\lib\site-packages\sympy\utilities\lambdify.py:880, in lambdify(args, expr, modules, printer, use_imps, dummify, cse, docstring_limit)
#     878 else:
#     879     cses, _expr = (), expr
# --> 880 funcstr = funcprinter.doprint(funcname, iterable_args, _expr, cses=cses)
#     882 # Collect the module imports from the code printers.
#     883 imp_mod_lines = []
#
# File C:\pythonhold\lib\site-packages\sympy\utilities\lambdify.py:1171, in _EvaluatorPrinter.doprint(self, funcname, args, expr, cses)
#    1168     else:
#    1169         funcbody.append('{} = {}'.format(self._exprrepr(s), self._exprrepr(e)))
# ...

# %%
figure, axis = plt.subplots(2,2)
axis[0,0].plot(t_vals, at_lam(t_vals), linestyle="-")
