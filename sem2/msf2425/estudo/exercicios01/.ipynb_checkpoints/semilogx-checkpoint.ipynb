# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
import math

rad = np.array([9.676 , 6.355, 4.261, 2.729, 1.862, 1.184, 0.7680, 0.4883, 0.3461, 0.2119])
t = np.array([0.6950, 4.363, 15.53, 38.74, 75.08, 125.2, 257.9, 344.1, 557.4, 690.7])
figure, axis = plt.subplots(2,2)
axis[0,0].scatter(t, rad)

# %%
axis[0,1].semilogx(t, rad, marker="o", linestyle="-")
figure
