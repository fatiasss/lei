# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
import math

m = np.array([0.15, 0.20, 0.16, 0.11, 0.25, 0.32, 0.40, 0.45, 0.50, 0.55])
t = np.array([1.21, 1.40, 1.26, 1.05, 1.60, 1.78, 2.00, 2.11, 2.22, 2.33])

# %%
figure, axis = plt.subplots(2,2)
axis[0,0].scatter(t, m)
axis[0,1].scatter(np.log(t), np.log(m))

# %%
def linreg(x,y):
    N = len(x)
    #sums of all elements, and sum of x**2
    sumx = np.sum(x)
    sumy = np.sum(y)
    sumxy = np.sum(x*y)
    sumxx = np.sum(np.square(x))
    sumyy = np.sum(np.square(y))
    #formulas
    m = ((N*sumxy)-(sumx*sumy))/((N*sumxx)-sumx**2)
    b = (sumxx*sumy-sumx*sumxy)/(N*sumxx-sumx**2)
    r2 = ((N*sumxy - sumx*sumy)**2)/((N*sumxx-sumx**2)*(N*sumyy-sumy**2))
    deltam = abs(m)*math.sqrt(((1/(r2**2))-1)/(N-2))
    deltab = deltam * math.sqrt((sumxx)/N)
    return m, b, r2, deltam, deltab
declive, b, r2, deltam, deltab = linreg(np.log(t), np.log(m))

# %%
declive, b, r2, deltam, deltab
# Out:
# (2.002118681850841,
#  -2.296202921613098,
#  0.9994184213605939,
#  0.02415202460991618,
#  0.013551494044773108)

# %%
be = math.exp(b)
axis[0,0].plot(t, be*t**m, linestyle="-")
axis[1,0].plot(t, be*t**m, linestyle="-")
figure

# %%
k = 4*(math.pi**2)*np.mean(m/t**2)
k
# Out:
# 3.977604885851136
