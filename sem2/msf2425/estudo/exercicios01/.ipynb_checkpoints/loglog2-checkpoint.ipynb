# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
import math

t = np.array([200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100])
e = np.arange(0, 50, 5)
figure, axis = plt.subplots(2,2)
axis[0,0].scatter(t, e)

# %%
axis[0,1].scatter(np.log(t), np.log(e))
figure
